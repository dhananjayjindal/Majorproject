ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/VS%20Codes/Major%20Project/Majorproject/matrix_stuff.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Dropping extra columns
# ----> <a href='vscode-notebook-cell:/c%3A/VS%20Codes/Major%20Project/Majorproject/matrix_stuff.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df.drop(['year'], axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/VS%20Codes/Major%20Project/Majorproject/matrix_stuff.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> axis = df.shape
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
#    5273         errors=errors,
#    5274     )
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['year'] not found in axis"

# %%
no_of_stocks = axis[1]
columns = df.columns

# %%
# Step 1 calculate returns (stockT2 - stockT1)/stockT1
returns = pd.DataFrame(index=range(axis[0]), columns=range(axis[1]))
for idx, col in enumerate(columns):
    for i in range(1, len(df[col])):
        s1 = df[col][i - 1]
        s2 = df[col][i]
        return_value = (s2 - s1) / s1
        returns[idx][i] = return_value

# returns = returns*100
returns.drop([0], axis=0, inplace=True)

# %%
returns
# Out:
#            0         1         2
# 1   0.268113   0.02204    0.0233
# 2  -0.087842  0.057158  0.029317
# 3   0.226917  0.017853  0.033799
# 4   0.163572  0.037114  0.038479
# 5    0.12356   0.00934  0.043244
# 6  -0.101045  0.052858  0.053997
# 7   0.239422 -0.030098  0.045038
# 8   0.110024  0.022478  0.060259
# 9  -0.084655 -0.056326  0.089642
# 10  0.039403  0.189177  0.049027
# 11  0.143006  0.112389  0.041402
# 12  0.189949  0.023851  0.053293
# 13 -0.146887   0.03295  0.099514
# 14 -0.264674  0.039964  0.085295
# 15  0.372287  0.055212  0.052006
# 16  0.239269   0.15562  0.046484
# 17 -0.071564  0.003785  0.065615
# 18  0.065708 -0.012631  0.100281
# 19  0.186094  0.012595  0.137821
# 20  0.325037 -0.024819  0.189007
# 21 -0.049233  0.040376   0.12368
# 22  0.215469  0.442793  0.089498
# 23  0.225552  0.012897  0.094717
# 24  0.062732   0.15286  0.083786
# 25   0.31727  0.322699  0.082702
# 26  0.186656  0.223899  0.069107
# 27  0.052502 -0.030311  0.067697
# 28  0.166084  0.068418  0.087593
# 29  0.316862  0.185385  0.084508
# 30  -0.03103  0.077368  0.073095
# 31  0.304641  0.193591  0.044298
# 32  0.076194  0.073398    0.0292
# 33  0.100787  0.130644    0.0296
# 34  0.013205 -0.073242  0.054505
# 35  0.375778  0.259433  0.056004
# 36  0.229603  0.001311  0.052895
# 37  0.333632  0.120231  0.054997
# 38   0.28579  0.144525  0.046806
# 39  0.210412 -0.075095  0.052999
# 40 -0.091046  0.172164  0.064002
# 41 -0.118855  0.055063  0.018195
# 42 -0.221003  0.151461  0.012402
# 43  0.286842  0.005359  0.009797

# %%
# Step 2 Calculation of Σ Covariance matrix between stocks from csv
Σ = returns.cov()

# %%
# Step 3 calcuating quadtric programming equation or objective function

# %%
# Step 3 calcualting geomean of returns constraint 1
returns_for_geomean = returns + 1
returns_for_geomean[0]
geo_mean = [
    (returns_for_geomean[i].prod() ** (1 / len(returns_for_geomean[i])) - 1)
    for i in returns_for_geomean
]
geo_mean = pd.DataFrame(geo_mean)

Σ.to_csv('covariance_matrix.csv', index=False)
geo_mean.to_csv('geomean.csv', index=False)

# %%
# Step 5 mean and of returns
µ = returns.mean()
µ.to_csv('mean_of_returns.csv', index=False)
